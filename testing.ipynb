# %%
import requests
import pandas as pd
import json
from flask import Flask
import os

# %%
# save variables
api_key = 'd94ec4df6e51870324d0daf2d3e8007e'
#lat = 42.944
#lon = -85.6213

# %%
url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={api_key}'

# Make the API call
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print('Error:', response.status_code, response.text)
# Out:
# {'lat': 42.944, 'lon': -85.6213, 'timezone': 'America/Detroit', 'timezone_offset': -14400, 'current': {'dt': 1719660947, 'sunrise': 1719655591, 'sunset': 1719710720, 'temp': 293.21, 'feels_like': 293.78, 'pressure': 1007, 'humidity': 96, 'dew_point': 292.55, 'uvi': 0.37, 'clouds': 100, 'visibility': 10000, 'wind_speed': 2.06, 'wind_deg': 210, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, 'minutely': [{'dt': 1719660960, 'precipitation': 0}, {'dt': 1719661020, 'precipitation': 0}, {'dt': 1719661080, 'precipitation': 0}, {'dt': 1719661140, 'precipitation': 0}, {'dt': 1719661200, 'precipitation': 0}, {'dt': 1719661260, 'precipitation': 0}, {'dt': 1719661320, 'precipitation': 0}, {'dt': 1719661380, 'precipitation': 0}, {'dt': 1719661440, 'precipitation': 0}, {'dt': 1719661500, 'precipitation': 0}, {'dt': 1719661560, 'precipitation': 0}, {'dt': 1719661620, 'precipitation': 0}, {'dt': 1719661680, 'precipitation': 0}, {'dt': 1719661740, 'precipitation': 0}, {'dt': 1719661800, 'precipitation': 0}, {'dt': 1719661860, 'precipitation': 0}, {'dt': 1719661920, 'precipitation': 0}, {'dt': 1719661980, 'precipitation': 0}, {'dt': 1719662040, 'precipitation': 0}, {'dt': 1719662100, 'precipitation': 0}, {'dt': 1719662160, 'precipitation': 0}, {'dt': 1719662220, 'precipitation': 0}, {'dt': 1719662280, 'precipitation': 0}, {'dt': 1719662340, 'precipitation': 0}, {'dt': 1719662400, 'precipitation': 0}, {'dt': 1719662460, 'precipitation': 0}, {'dt': 1719662520, 'precipitation': 0}, {'dt': 1719662580, 'precipitation': 0}, {'dt': 1719662640, 'precipitation': 0}, {'dt': 1719662700, 'precipitation': 0}, {'dt': 1719662760, 'precipitation': 0}, {'dt': 1719662820, 'precipitation': 0}, {'dt': 1719662880, 'precipitation': 0}, {'dt': 1719662940, 'precipitation': 0}, {'dt': 1719663000, 'precipitation': 0}, {'dt': 1719663060, 'precipitation': 0}, {'dt': 1719663120, 'precipitation': 0}, {'dt': 1719663180, 'precipitation': 0}, {'dt': 1719663240, 'precipitation': 0}, {'dt': 1719663300, 'precipitation': 0}, {'dt': 1719663360, 'precipitation': 0}, {'dt': 1719663420, 'precipitation': 0}, {'dt': 1719663480, 'precipitation': 0}, {'dt': 1719663540, 'precipitation': 0}, {'dt': 1719663600, 'precipitation': 0}, {'dt': 1719663660, 'precipitation': 0}, {'dt': 1719663720, 'precipitation': 0}, {'dt': 1719663780, 'precipitation': 0}, {'dt': 1719663840, 'precipitation': 0}, {'dt': 1719663900, 'precipitation': 0}, {'dt': 1719663960, 'precipitation': 0}, {'dt': 1719664020, 'precipitation': 0}, {'dt': 1719664080, 'precipitation': 0}, {'dt': 1719664140, 'precipitation': 0}, {'dt': 1719664200, 'precipitation': 0}, {'dt': 1719664260, 'precipitation': 0}, {'dt': 1719664320, 'precipitation': 0}, {'dt': 1719664380, 'precipitation': 0}, {'dt': 1719664440, 'precipitation': 0}, {'dt': 1719664500, 'precipitation': 0}], 'hourly': [{'dt': 1719658800, 'temp': 293.57, 'feels_like': 294.2, 'pressure': 1007, 'humidity': 97, 'dew_point': 293.08, 'uvi': 0.12, 'clouds': 100, 'visibility': 10000, 'wind_speed': 5.57, 'wind_deg': 215, 'wind_gust': 12.9, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'pop': 1, 'rain': {'1h': 0.13}}, {'dt': 1719662400, 'temp': 293.21, 'feels_like': 293.78, 'pressure': 1007, 'humidity': 96, 'dew_point': 292.55, 'uvi': 0.37, 'clouds': 100, 'visibility': 10000, 'wind_speed': 5.77, 'wind_deg': 222, 'wind_gust': 12.42, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719666000, 'temp': 293.77, 'feels_like': 294.37, 'pressure': 1007, 'humidity': 95, 'dew_point': 292.94, 'uvi': 1.11, 'clouds': 100, 'visibility': 10000, 'wind_speed': 6.5, 'wind_deg': 231, 'wind_gust': 11.84, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1719669600, 'temp': 294.41, 'feels_like': 295.07, 'pressure': 1007, 'humidity': 95, 'dew_point': 293.58, 'uvi': 0.78, 'clouds': 100, 'visibility': 10 ...

# %%
# define functions
# get geo data from zipcode
def get_geolocation(zip_code, api_key):
    base_url = 'https://api.openweathermap.org/geo/1.0/zip'
    params = {
        'zip': zip_code,
        'appid': api_key
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print('Error:', response.status_code, response.text)
        return None

#get weather from geodata
def get_weather(lat, lon, api_key):
    base_url = 'https://api.openweathermap.org/data/2.5/weather'
    params = {
        'lat': lat,
        'lon': lon,
        'appid': api_key,
        'units': imperial
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print('Error:', response.status_code, response.text)
        return None

# main function: get weather from geodata
def main():
    # api key
    api_key = 'd94ec4df6e51870324d0daf2d3e8007e'
    # zip code and country code
    zip_code = '49506,US'

    # get geodata
    geo_data = get_geolocation(zip_code, api_key)
    if geo_data:
        lat = geo_data['lat']
        lon = geo_data['lon']
        print(f"Latitude: {lat}, Longitude: {lon}")

        # get weather
        weather_data = get_weather(lat, lon, api_key)
        if weather_data:
            print(weather_data)

# %%
def fetch_weather_data(lat, lon, api_key):
    api_url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={api_key}'
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        save_weather_data(data)
        return data
    else:
        print("Failed to fetch data:", response.status_code)
        return None

# %%
def save_weather_data(data):
    with open('data/weather_data.json', 'w') as f:
        json.dump(data, f, indent=4)

# %%
def load_weather_data():
    with open('data/weather_data.json', 'r') as f:
        data = json.load(f)
    return data

# %%
data = fetch_weather_data(lat, lon, api_key)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data = fetch_weather_data(lat, lon, api_key)
#       2 print(data)
#
# Cell In[24], line 6, in fetch_weather_data(lat, lon, api_key)
#       4 if response.status_code == 200:
#       5     data = response.json()
# ----> 6     save_weather_data(data)
#       7     return data
#       8 else:
#
# Cell In[25], line 2, in save_weather_data(data)
#       1 def save_weather_data(data):
# ----> 2     with open('data/weather_data.json', 'w') as f:
#       3         json.dump(data, f, indent=4)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/weather_data.json'

# %%
import requests
import json
import os

# Ensure 'data' directory exists
os.makedirs('data', exist_ok=True)

# Fetch weather data from the API
def fetch_weather_data(lat, lon, api_key):
    api_url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={api_key}'
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        save_weather_data(data)
        return data
    else:
        print("Failed to fetch data:", response.status_code)
        return None

# Save weather data to a file
def save_weather_data(data):
    os.makedirs('data', exist_ok=True)  # Create 'data' directory if it doesn't exist
    with open('data/weather_data.json', 'w') as f:
        json.dump(data, f, indent=4)

# Load weather data from a file
def load_weather_data():
    if not os.path.exists('data/weather_data.json'):
        print("File not found. Fetching new data.")
        return None
    with open('data/weather_data.json', 'r') as f:
        data = json.load(f)
    return data

# Replace these with actual values
api_key = 'd94ec4df6e51870324d0daf2d3e8007e'
lat = 42.944
lon = -85.6213

# Test the entire workflow
data = fetch_weather_data(lat, lon, api_key)
if data:
    print("Fetched Data:", data)
    loaded_data = load_weather_data()
    print("Loaded Data:", loaded_data)
else:
    print("No data fetched.")
# Out:
# Fetched Data: {'lat': 42.944, 'lon': -85.6213, 'timezone': 'America/Detroit', 'timezone_offset': -14400, 'current': {'dt': 1719665205, 'sunrise': 1719655591, 'sunset': 1719710720, 'temp': 294.11, 'feels_like': 294.74, 'pressure': 1008, 'humidity': 95, 'dew_point': 293.28, 'uvi': 1.11, 'clouds': 100, 'visibility': 10000, 'wind_speed': 2.57, 'wind_deg': 180, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, 'minutely': [{'dt': 1719665220, 'precipitation': 0}, {'dt': 1719665280, 'precipitation': 0}, {'dt': 1719665340, 'precipitation': 0}, {'dt': 1719665400, 'precipitation': 0}, {'dt': 1719665460, 'precipitation': 0}, {'dt': 1719665520, 'precipitation': 0}, {'dt': 1719665580, 'precipitation': 0}, {'dt': 1719665640, 'precipitation': 0}, {'dt': 1719665700, 'precipitation': 0}, {'dt': 1719665760, 'precipitation': 0}, {'dt': 1719665820, 'precipitation': 0}, {'dt': 1719665880, 'precipitation': 0}, {'dt': 1719665940, 'precipitation': 0}, {'dt': 1719666000, 'precipitation': 0}, {'dt': 1719666060, 'precipitation': 0}, {'dt': 1719666120, 'precipitation': 0}, {'dt': 1719666180, 'precipitation': 0}, {'dt': 1719666240, 'precipitation': 0}, {'dt': 1719666300, 'precipitation': 0}, {'dt': 1719666360, 'precipitation': 0}, {'dt': 1719666420, 'precipitation': 0}, {'dt': 1719666480, 'precipitation': 0}, {'dt': 1719666540, 'precipitation': 0}, {'dt': 1719666600, 'precipitation': 0}, {'dt': 1719666660, 'precipitation': 0}, {
 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719666000, 'temp': 294.11, 'feels_like': 294.74, 'pressure': 1008, 'humidity': 95, 'dew_point': 293.28, 'uvi': 1.11, 'clouds': 100, 'visibility': 10000, 'wind_speed': 5.35, 'wind_deg': 241, 'wind_gust': 10.33, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719669600, 'temp': 294.72, 'feels_like': 295.39, 'pressure': 1008, 'humidity': 94, 'dew_point': 293.71, 'uvi': 0.78, 'clouds': 99, 'visibility': 10000, 'wind_speed': 6.06, 'wind_deg': 254, 'wind_gust': 9.98, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719673200, 'temp': 295.45, 'feels_like': 296.16, 'pressure': 1008, 'humidity': 93, 'dew_point': 294.26, 'uvi': 0.76, 'clouds': 96, 'visibility':  ...

# %%
# Constants (if they won't change)
api_key = 'd94ec4df6e51870324d0daf2d3e8007e'
lat = 42.944
lon = -85.6213

# Fetch weather data from the API
def fetch_weather_data(lat, lon, api_key):
    api_url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&appid={api_key}'
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Failed to fetch data:", response.status_code)
        return None

data = fetch_weather_data(lat, lon, api_key)
print(data)
# Out:
# {'lat': 42.944, 'lon': -85.6213, 'timezone': 'America/Detroit', 'timezone_offset': -14400, 'current': {'dt': 1719668773, 'sunrise': 1719655591, 'sunset': 1719710720, 'temp': 295.89, 'feels_like': 296.67, 'pressure': 1008, 'humidity': 94, 'dew_point': 294.87, 'uvi': 0.78, 'clouds': 100, 'visibility': 10000, 'wind_speed': 3.6, 'wind_deg': 210, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, 'minutely': [{'dt': 1719668820, 'precipitation': 0}, {'dt': 1719668880, 'precipitation': 0}, {'dt': 1719668940, 'precipitation': 0}, {'dt': 1719669000, 'precipitation': 0}, {'dt': 1719669060, 'precipitation': 0}, {'dt': 1719669120, 'precipitation': 0}, {'dt': 1719669180, 'precipitation': 0}, {'dt': 1719669240, 'precipitation': 0}, {'dt': 1719669300, 'precipitation': 0}, {'dt': 1719669360, 'precipitation': 0}, {'dt': 1719669420, 'precipitation': 0}, {'dt': 1719669480, 'precipitation': 0}, {'dt': 1719669540, 'precipitation': 0}, {'dt': 1719669600, 'precipitation': 0}, {'dt': 1719669660, 'precipitation': 0}, {'dt': 1719669720, 'precipitation': 0}, {'dt': 1719669780, 'precipitation': 0}, {'dt': 1719669840, 'precipitation': 0}, {'dt': 1719669900, 'precipitation': 0}, {'dt': 1719669960, 'precipitation': 0}, {'dt': 1719670020, 'precipitation': 0}, {'dt': 1719670080, 'precipitation': 0}, {'dt': 1719670140, 'precipitation': 0}, {'dt': 1719670200, 'precipitation': 0}, {'dt': 1719670260, 'precipitation': 0}, {'dt': 1719670320, 'precipitation': 0}, {'dt': 1719670380, 'precipitation': 0}, {'dt': 1719670440, 'precipitation': 0}, {'dt': 1719670500, 'precipitation': 0}, {'dt': 1719670560, 'precipitation': 0}, {'dt': 1719670620, 'precipitation': 0}, {'dt': 1719670680, 'precipitation': 0}, {'dt': 1719670740, 'precipitation': 0}, {'dt': 1719670800, 'precipitation': 0}, {'dt': 1719670860, 'precipitation': 0}, {'dt': 1719670920, 'precipitation': 0}, {'dt': 1719670980, 'precipitation': 0}, {'dt': 1719671040, 'precipitation': 0}, {'dt': 1719671100, 'precipitation': 0}, {'dt': 1719671160, 'precipitation': 0}, {'dt': 1719671220, 'precipitation': 0}, {'dt': 1719671280, 'precipitation': 0}, {'dt': 1719671340, 'precipitation': 0}, {'dt': 1719671400, 'precipitation': 0}, {'dt': 1719671460, 'precipitation': 0}, {'dt': 1719671520, 'precipitation': 0}, {'dt': 1719671580, 'precipitation': 0}, {'dt': 1719671640, 'precipitation': 0}, {'dt': 1719671700, 'precipitation': 0}, {'dt': 1719671760, 'precipitation': 0}, {'dt': 1719671820, 'precipitation': 0}, {'dt': 1719671880, 'precipitation': 0}, {'dt': 1719671940, 'precipitation': 0}, {'dt': 1719672000, 'precipitation': 0}, {'dt': 1719672060, 'precipitation': 0}, {'dt': 1719672120, 'precipitation': 0}, {'dt': 1719672180, 'precipitation': 0}, {'dt': 1719672240, 'precipitation': 0}, {'dt': 1719672300, 'precipitation': 0}, {'dt': 1719672360, 'precipitation': 0}], 'hourly': [{'dt': 1719666000, 'temp': 295.98, 'feels_like': 296.8, 'pressure': 1008, 'humidity': 95, 'dew_point': 295.14, 'uvi': 1.11, 'clouds': 100, 'visibility': 10000, 'wind_speed': 5.35, 'wind_deg': 241, 'wind_gust': 10.33, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'pop': 1, 'rain': {'1h': 0.29}}, {'dt': 1719669600, 'temp': 295.89, 'feels_like': 296.67, 'pressure': 1008, 'humidity': 94, 'dew_point': 294.87, 'uvi': 0.78, 'clouds': 100, 'visibility': 10000, 'wind_speed': 6.06, 'wind_deg': 254, 'wind_gust': 9.98, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719673200, 'temp': 296.2, 'feels_like': 296.99, 'pressure': 1008, 'humidity': 93, 'dew_point': 295.01, 'uvi': 0.76, 'clouds': 98, 'visibility': 10000, 'wind_speed': 6.93, 'wind_deg': 259, 'wind_gust': 10.2, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'pop': 0.8}, {'dt': 1719676800, 'temp': 295.98, 'feels_like': 296.75, 'pressure': 1008, 'humidity': 93, 'dew_point': 294.79, 'uvi': 1.81, 'clouds': 96, 'visibility': 1000 ...

# %%
weather = data
print(weather['current']['weather'][0]['main'])
# Out:
# Clouds

# %%
zipcode = 49506

# get geo data from zipcode
def get_geolocation(zip_code, api_key):
    base_url = 'https://api.openweathermap.org/geo/1.0/zip'
    params = {
        'zip': zipcode,
        'appid': api_key
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print('Error:', response.status_code, response.text)
        return None

# %%
get_geolocation(zipcode, api_key)
# Out:
# {'zip': '49506',
#  'name': 'East Grand Rapids',
#  'lat': 42.944,
#  'lon': -85.6213,
#  'country': 'US'}
